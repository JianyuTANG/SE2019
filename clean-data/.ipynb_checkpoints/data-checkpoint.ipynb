# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_excel("clean-data/data.xls")

# %%
df
# Out:
#     标签信息 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Part１　基本信息 Unnamed: 6  \
# 0     姓名         期数       期内职务       从事行业         NaN         性别         生肖
# 1    王舜尧          1        辅导员         金融         NaN          男          猴
# 2   周  昕          1         学员       管理咨询         NaN          男          狗
# 3    韩海峰          1         学员         金融         NaN          男          猪
# 4    顾功尧          1         学员         汽车         NaN          男          鼠
# 5   尚  媛          1         学员    政府，国际交流         NaN          女          猪
# 6   乐  园          1         学员    企业，交通运输         NaN          女          猪
# 7    蔡望鹏          1         学员         基金         NaN          男          猪
# 8   满  毅          1         学员         化工         NaN          男          狗
# 9   杨  帆          1         学员         教育         NaN          女          猪
# 10  刘  雯          1         理事        房地产         NaN          女          猪
# ...

# %%
# Out:
# '/Users/vincent/OneDrive - mails.tsinghua.edu.cn/code/SE2019'
